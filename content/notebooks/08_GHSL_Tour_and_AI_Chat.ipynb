# %% [markdown]
# # GHSL Global Tour + AI Chat
#
# This notebook is a companion to `global/Global_Human_Settlements_Tour.jGIS`. The deployed JupyterLite includes **jupyterlite-ai**. Open the AI/chat sidebar to ask questions while exploring the story map.

# %% [markdown]
# ## Safe interpretation
#
# GHSL urban centres describe harmonized human-settlement entities. They are **not** an informal-settlement classification. Use explicit informal-settlement sources for claims about informality.

# %%
import json
from pathlib import Path
p = Path('../global/ghsl_urban_centres.geojson')
if p.exists():
    data = json.loads(p.read_text())
    print(f"GHSL urban centres available in this build: {len(data['features']):,}")
else:
    print('GHSL generated catalog is created by the GitHub Pages build.')

# %% [markdown]
# ## Suggested AI prompts
#
# - Compare the largest centres in a selected country.
# - Explain the GHSL built-up surface fields.
# - Write Python to filter the compact GeoJSON by `country_iso3`.
# - Explain why GHSL urban-centre status should not be treated as evidence of informality.
